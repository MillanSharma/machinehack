# %%
import numpy as np
import pandas as pd
train=pd.read_excel('Data_Train.xlsx')

# %%
test=pd.read_excel('Data_Test.xlsx')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
# Name                 6019 non-null object
# Location             6019 non-null object
# Year                 6019 non-null int64
# Kilometers_Driven    6019 non-null int64
# Fuel_Type            6019 non-null object
# Transmission         6019 non-null object
# Owner_Type           6019 non-null object
# Mileage              6017 non-null object
# Engine               5983 non-null object
# Power                5983 non-null object
# Seats                5977 non-null float64
# New_Price            824 non-null object
# Price                6019 non-null float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 611.4+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 12 columns):
# Name                 1234 non-null object
# Location             1234 non-null object
# Year                 1234 non-null int64
# Kilometers_Driven    1234 non-null int64
# Fuel_Type            1234 non-null object
# Transmission         1234 non-null object
# Owner_Type           1234 non-null object
# Mileage              1234 non-null object
# Engine               1224 non-null object
# Power                1224 non-null object
# Seats                1223 non-null float64
# New_Price            182 non-null object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 115.8+ KB

# %%
train.isna().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
test.isna().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                 10
# Power                  10
# Seats                  11
# New_Price            1052
# dtype: int64

# %%
train.Fuel_Type.unique()
train.Seats.unique()
# train.info()
train.Transmission.unique()
train.Engine.unique()
# Out:
# array(['998 CC', '1582 CC', '1199 CC', '1248 CC', '1968 CC', '814 CC',
#        '1461 CC', '2755 CC', '1598 CC', '1462 CC', '1497 CC', '2179 CC',
#        '2477 CC', '1498 CC', '2143 CC', '1995 CC', '1984 CC', '1197 CC',
#        '2494 CC', '1798 CC', '2696 CC', '2698 CC', '1061 CC', '1198 CC',
#        '2987 CC', '796 CC', '624 CC', '1999 CC', '1991 CC', '2694 CC',
#        '1120 CC', '2498 CC', '799 CC', '2393 CC', '1399 CC', '1796 CC',
#        '2148 CC', '1396 CC', '1950 CC', '4806 CC', '1998 CC', '1086 CC',
#        '1193 CC', '2982 CC', '1493 CC', '2967 CC', '2993 CC', '1196 CC',
#        '1799 CC', '2497 CC', '2354 CC', '1373 CC', '2996 CC', '1591 CC',
#        '2894 CC', '5461 CC', '1595 CC', '936 CC', '1997 CC', nan,
#        '1896 CC', '1390 CC', '1364 CC', '2199 CC', '993 CC', '999 CC',
#        '1405 CC', '2956 CC', '1794 CC', '995 CC', '2496 CC', '1599 CC',
#        '2400 CC', '1495 CC', '2523 CC', '793 CC', '4134 CC', '1596 CC',
# ...

# %%
train['Mileage']=train.Mileage.str.extract('(^\d*)')
train.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First      26   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First      19  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First      18  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First      20  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second      15  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# 2  8.61 Lakh   4.50
# ...

# %%
train['Engine']=train.Engine.str.extract('(^\d*)')
train.head(10)
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 5      Hyundai EON LPG Era Plus Option   Hyderabad  2012              75000
# 6               Nissan Micra Diesel XV      Jaipur  2013              86999
# 7    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016              36000
# 8  Volkswagen Vento Diesel Comfortline        Pune  2013              64430
# 9       Tata Indica Vista Quadrajet LS     Chennai  2012              65932
#
#   Fuel_Type Transmission Owner_Type Mileage Engine      Power  Seats  \
# ...

# %%
train['Power']=train.Power.str.extract('(^\d*)')
train.head(10)
# train.info()
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 5      Hyundai EON LPG Era Plus Option   Hyderabad  2012              75000
# 6               Nissan Micra Diesel XV      Jaipur  2013              86999
# 7    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016              36000
# 8  Volkswagen Vento Diesel Comfortline        Pune  2013              64430
# 9       Tata Indica Vista Quadrajet LS     Chennai  2012              65932
#
#   Fuel_Type Transmission Owner_Type Mileage Engine Power  Seats  New_Price  \
# ...

# %%
train.Owner_Type.unique()
# Out:
# array(['First', 'Second', 'Fourth & Above', 'Third'], dtype=object)

# %%
train.Power = pd.to_numeric(train.Power, errors='coerce')
train.Mileage = pd.to_numeric(train.Mileage, errors='coerce')

# tratrain.Mileage
# (train.Mileage, errors='coerce')
# ID = pd.to_numeric(ID, errors='coerce')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
# Name                 6019 non-null object
# Location             6019 non-null object
# Year                 6019 non-null int64
# Kilometers_Driven    6019 non-null int64
# Fuel_Type            6019 non-null object
# Transmission         6019 non-null object
# Owner_Type           6019 non-null object
# Mileage              6017 non-null float64
# Engine               5983 non-null object
# Power                5876 non-null float64
# Seats                5977 non-null float64
# New_Price            824 non-null object
# Price                6019 non-null float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 611.4+ KB

# %%
train.Engine = pd.to_numeric(train.Engine, errors='coerce')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
# Name                 6019 non-null object
# Location             6019 non-null object
# Year                 6019 non-null int64
# Kilometers_Driven    6019 non-null int64
# Fuel_Type            6019 non-null object
# Transmission         6019 non-null object
# Owner_Type           6019 non-null object
# Mileage              6017 non-null float64
# Engine               5983 non-null float64
# Power                5876 non-null float64
# Seats                5977 non-null float64
# New_Price            824 non-null object
# Price                6019 non-null float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 611.4+ KB

# %%
# train.New_Price = pd.to_numeric(train.New_Price, errors='coerce')
train.isna().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                 143
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
train.describe()
# Out:
#               Year  Kilometers_Driven      Mileage       Engine        Power  \
# count  6019.000000       6.019000e+03  6017.000000  5983.000000  5876.000000
# mean   2013.358199       5.873838e+04    17.710487  1621.276450   112.938223
# std       3.269742       9.126884e+04     4.579195   601.355233    53.917208
# min    1998.000000       1.710000e+02     0.000000    72.000000    34.000000
# 25%    2011.000000       3.400000e+04    15.000000  1198.000000    75.000000
# 50%    2014.000000       5.300000e+04    18.000000  1493.000000    97.000000
# 75%    2016.000000       7.300000e+04    21.000000  1984.000000   138.000000
# max    2019.000000       6.500000e+06    33.000000  5998.000000   560.000000
#
#              Seats        Price
# count  5977.000000  6019.000000
# mean      5.278735     9.479468
# std       0.808840    11.187917
# min       0.000000     0.440000
# 25%       5.000000     3.500000
# 50%       5.000000     5.640000
# 75%       5.000000     9.950000
# ...

# %%
train.Price = pd.to_numeric(train.Price, errors='coerce')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
# Name                 6019 non-null object
# Location             6019 non-null object
# Year                 6019 non-null int64
# Kilometers_Driven    6019 non-null int64
# Fuel_Type            6019 non-null object
# Transmission         6019 non-null object
# Owner_Type           6019 non-null object
# Mileage              6017 non-null float64
# Engine               5983 non-null float64
# Power                5876 non-null float64
# Seats                5977 non-null float64
# New_Price            824 non-null object
# Price                6019 non-null float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 611.4+ KB

# %%
# df["Sex"]=df["Sex"].replace(["male","female"],[0,1])
train["Owner_Type"]=train["Owner_Type"].replace(['First','Second','Third','Fourth & Above'],[5,3,2,1])
train["Transmission"]=train["Transmission"].replace(['Manual','Automatic'],[1,3]).astype(int)
train["Fuel_Type"]=train["Fuel_Type"].replace(['CNG','LPG','Petrol','Diesel','Electric'],[2,2,3,2,4]).astype(int)

# %%
train.describe()
# Out:
#               Year  Kilometers_Driven    Fuel_Type  Transmission   Owner_Type  \
# count  6019.000000       6.019000e+03  6019.000000   6019.000000  6019.000000
# mean   2013.358199       5.873838e+04     2.456887      1.571524     4.616049
# std       3.269742       9.126884e+04     0.498846      0.903628     0.829989
# min    1998.000000       1.710000e+02     2.000000      1.000000     1.000000
# 25%    2011.000000       3.400000e+04     2.000000      1.000000     5.000000
# 50%    2014.000000       5.300000e+04     2.000000      1.000000     5.000000
# 75%    2016.000000       7.300000e+04     3.000000      3.000000     5.000000
# max    2019.000000       6.500000e+06     4.000000      3.000000     5.000000
#
#            Mileage       Engine        Power        Seats        Price
# count  6017.000000  5983.000000  5876.000000  5977.000000  6019.000000
# mean     17.710487  1621.276450   112.938223     5.278735     9.479468
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
# Name                 6019 non-null object
# Location             6019 non-null object
# Year                 6019 non-null int64
# Kilometers_Driven    6019 non-null int64
# Fuel_Type            6019 non-null int32
# Transmission         6019 non-null int32
# Owner_Type           6019 non-null int64
# Mileage              6017 non-null float64
# Engine               5983 non-null float64
# Power                5876 non-null float64
# Seats                5977 non-null float64
# New_Price            824 non-null object
# Price                6019 non-null float64
# dtypes: float64(5), int32(2), int64(3), object(3)
# memory usage: 564.4+ KB

# %%
train = train.drop(["New_Price"],axis="columns")

# %%
train["Engine"][train["Engine"].isna()]=train["Engine"].max()
# Out:
# C:\Users\Millan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# train["Power"][train["Power"].isna()]=train["Power"].mean()
# train.info()
train["Seats"][train["Seats"].isna()]=train["Seats"].mean()
train["Mileage"][train["Mileage"].isna()]=train["Mileage"].mean()

train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 12 columns):
# Name                 6019 non-null object
# Location             6019 non-null object
# Year                 6019 non-null int64
# Kilometers_Driven    6019 non-null int64
# Fuel_Type            6019 non-null int32
# Transmission         6019 non-null int32
# Owner_Type           6019 non-null int64
# Mileage              6019 non-null float64
# Engine               6019 non-null float64
# Power                6019 non-null float64
# Seats                6019 non-null float64
# Price                6019 non-null float64
# dtypes: float64(5), int32(2), int64(3), object(2)
# memory usage: 517.4+ KB
# C:\Users\Millan\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# train = train.drop(["Name","Location",],axis="columns")

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

from sklearn.model_selection import train_test_split

# %%
y=train["Price"]
train.drop("Price",axis="columns",inplace=True)
X=train

# %%
#  model =RandomForestClassifier()
model = LinearRegression()
# model = XGBClassifier()

             
             
             
X_train, X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=23)
model.fit(X_train,y_train)
print(model.score(X_test,y_test))
# model.fit(X,y)
# print("Prediction on outside data",model.score(X,y))
# Out:
# 0.7315706018043016
